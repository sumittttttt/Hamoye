# %% [markdown]
# # Hamoye Stage B - Quiz Answers

# %%
#importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Getting data

# %%
data = pd.read_csv('energydata_complete.csv')
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
# setting to display all rows and columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4       RH_4         T5   RH_5        T6  \
# 0  19.79  44.730000  19.000000  45.566667  17.166667  55.20  7.026667
# 1  19.79  44.790000  19.000000  45.992500  17.166667  55.20  6.833333
# 2  19.79  44.933333  18.926667  45.890000  17.166667  55.09  6.560000
# 3  19.79  45.000000  18.890000  45.723333  17.166667  55.09  6.433333
# 4  19.79  45.000000  18.890000  45.530000  17.200000  55.09  6.366667
#
#         RH_6         T7       RH_7    T8       RH_8         T9   RH_9  \
# ...

# %%
data_temp= data.drop(columns=['date','lights'],axis=1)

# %%
data_temp.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5   RH_5        T6       RH_6         T7       RH_7  \
# 0  45.566667  17.166667  55.20  7.026667  84.256667  17.200000  41.626667
# 1  45.992500  17.166667  55.20  6.833333  84.063333  17.200000  41.560000
# 2  45.890000  17.166667  55.09  6.560000  83.156667  17.200000  41.433333
# 3  45.723333  17.166667  55.09  6.433333  83.423333  17.133333  41.290000
# 4  45.530000  17.200000  55.09  6.366667  84.893333  17.200000  41.230000
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data_normalised = pd.DataFrame(scaler.fit_transform(data_temp), columns=data_temp.columns)

# %%
data_normalised.head()
# Out:
#    Appliances       T1      RH_1        T2      RH_2        T3      RH_3  \
# 0    0.046729  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066
# 1    0.046729  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871
# 2    0.037383  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569
# 3    0.037383  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685
# 4    0.046729  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685
#
#          T4      RH_4        T5      RH_5        T6      RH_6        T7  \
# 0  0.351351  0.764262  0.175506  0.381691  0.381070  0.841827  0.170594
# 1  0.351351  0.782437  0.175506  0.381691  0.375443  0.839872  0.170594
# 2  0.344745  0.778062  0.175506  0.380037  0.367487  0.830704  0.170594
# 3  0.341441  0.770949  0.175506  0.380037  0.363800  0.833401  0.164310
# 4  0.341441  0.762697  0.178691  0.380037  0.361859  0.848264  0.170594
#
#        RH_7        T8      RH_8        T9      RH_9     T_out  Press_mm_hg  \
# ...

# %%
#getting normalised X and y
norm_X = data_normalised.drop('Appliances',axis=1)
norm_y = data_normalised['Appliances']

# %%
norm_X.head()
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5        T6      RH_6        T7      RH_7  \
# 0  0.764262  0.175506  0.381691  0.381070  0.841827  0.170594  0.653428
# 1  0.782437  0.175506  0.381691  0.375443  0.839872  0.170594  0.651064
# 2  0.778062  0.175506  0.380037  0.367487  0.830704  0.170594  0.646572
# 3  0.770949  0.175506  0.380037  0.363800  0.833401  0.164310  0.641489
# 4  0.762697  0.178691  0.380037  0.361859  0.848264  0.170594  0.639362
#
#          T8      RH_8        T9      RH_9     T_out  Press_mm_hg    RH_out  \
# ...

# %%
norm_y.head()
# Out:
# 0    0.046729
# 1    0.046729
# 2    0.037383
# 3    0.037383
# 4    0.046729
# Name: Appliances, dtype: float64

# %% [markdown]
# ### Question 12
# From the dataset, fit a linear model on the relationship between the temperature in the living room in Celsius(x = T2) and the temperature outside the building (y = T6). Whats is the R^2 value in two D.P?

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4       RH_4         T5   RH_5        T6  \
# 0  19.79  44.730000  19.000000  45.566667  17.166667  55.20  7.026667
# 1  19.79  44.790000  19.000000  45.992500  17.166667  55.20  6.833333
# 2  19.79  44.933333  18.926667  45.890000  17.166667  55.09  6.560000
# 3  19.79  45.000000  18.890000  45.723333  17.166667  55.09  6.433333
# 4  19.79  45.000000  18.890000  45.530000  17.200000  55.09  6.366667
#
#         RH_6         T7       RH_7    T8       RH_8         T9   RH_9  \
# ...

# %%
#getting x and y
x = data.iloc[:, 5].values  
y = data.iloc[:, 13].values

# %%
x
# Out:
# array([19.2       , 19.2       , 19.2       , ..., 25.62857143,
#        25.414     , 25.26428571])

# %%
y
# Out:
# array([ 7.02666667,  6.83333333,  6.56      , ..., 23.62666667,
#        22.43333333, 21.02666667])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
x_train = x_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics
predicted_values = model.predict(x_test.reshape(-1,1))

print('R2 score', round(metrics.r2_score(y_test,predicted_values),2))
# Out:
# R2 score 0.64

# %% [markdown]
# ### Question 13
# What is the Mean Absolute Error (in two decimal places)?

# %%
print('Mean Absolute Error (MAE)', round(metrics.mean_absolute_error(y_test,predicted_values),2))
# Out:
# Mean Absolute Error (MAE) 2.82

# %% [markdown]
# ### Question 14
# What is the Residual Sum of Squares(in two decimal places)

# %%
rss = np.sum(np.square(y_test - predicted_values))
print("Residual Sum os Squares", round(rss, 2))
# Out:
# Residual Sum os Squares 2125560497.02

# %% [markdown]
# ### Question 15
# What is the Root Mean Squared Error(in three decimal places)?

# %%
rmse = np.sqrt(metrics.mean_squared_error(y_test,predicted_values))
print('Root Mean Squared Error', round(rmse,3))b
# Out:
# Root Mean Squared Error 3.63

# %% [markdown]
# ### Question 16
# What is the coefficient of determination (in two decimal places)

# %% [markdown]
# Answer: Same as Question 12 - **0.64**

# %% [markdown]
# ### Question 17
# Obtain the feature weights from your linear model above. Which features have the lowest and highest weights respectively?

# %%
#fitting our liner model with normalised dataset
norm_X_train, norm_X_test, norm_y_train, norm_y_test = train_test_split(norm_X, norm_y,test_size=0.3,random_state=42)
model_1 = LinearRegression()
model_1.fit(norm_X_train, norm_y_train)
# Out:
# LinearRegression()

# %%
imp = model_1.coef_
for i,v in enumerate(imp):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(imp))], imp)
plt.show()
# Out:
# Feature: 0, Score: -0.00328
# Feature: 1, Score: 0.55351
# Feature: 2, Score: -0.23619
# Feature: 3, Score: -0.45670
# Feature: 4, Score: 0.29064
# Feature: 5, Score: 0.09608
# Feature: 6, Score: 0.02899
# Feature: 7, Score: 0.02640
# Feature: 8, Score: -0.01567
# Feature: 9, Score: 0.01601
# Feature: 10, Score: 0.23645
# Feature: 11, Score: 0.03804
# Feature: 12, Score: 0.01035
# Feature: 13, Score: -0.04462
# Feature: 14, Score: 0.10199
# Feature: 15, Score: -0.15758
# Feature: 16, Score: -0.18996
# Feature: 17, Score: -0.03982
# Feature: 18, Score: -0.32186
# Feature: 19, Score: 0.00683
# Feature: 20, Score: -0.07766
# Feature: 21, Score: 0.02918
# Feature: 22, Score: 0.01231
# Feature: 23, Score: 0.11775
# Feature: 24, Score: 63137500318.08096
# Feature: 25, Score: -63137500318.07938

# %% [markdown]
# Answer is option B

# %% [markdown]
# ### Question 19
# Train a lasso regression model with an alpha value of 0.001 and obtain the new feature weights with it. How many of the features have non-zero weights?

# %%
from sklearn.linear_model import Lasso
model_2 = Lasso(alpha=0.001)
model_2.fit(norm_X_train, norm_y_train)
# Out:
# Lasso(alpha=0.001)

# %%
imp_1 = model_2.coef_
for i,v in enumerate(imp_1):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(imp_1))], imp_1)
plt.show()
# Out:
# Feature: 0, Score: 0.00000
# Feature: 1, Score: 0.01788
# Feature: 2, Score: 0.00000
# Feature: 3, Score: -0.00000
# Feature: 4, Score: 0.00000
# Feature: 5, Score: 0.00000
# Feature: 6, Score: -0.00000
# Feature: 7, Score: 0.00000
# Feature: 8, Score: -0.00000
# Feature: 9, Score: 0.00000
# Feature: 10, Score: 0.00000
# Feature: 11, Score: -0.00000
# Feature: 12, Score: -0.00000
# Feature: 13, Score: -0.00000
# Feature: 14, Score: 0.00000
# Feature: 15, Score: -0.00011
# Feature: 16, Score: -0.00000
# Feature: 17, Score: -0.00000
# Feature: 18, Score: 0.00000
# Feature: 19, Score: -0.00000
# Feature: 20, Score: -0.04956
# Feature: 21, Score: 0.00291
# Feature: 22, Score: 0.00000
# Feature: 23, Score: 0.00000
# Feature: 24, Score: -0.00000
# Feature: 25, Score: -0.00000

# %%
preds = model_2.predict(norm_X_test)

# %% [markdown]
# ### Question 20
# What is the new RMSE with Lasso Regression (in three decimal places)

# %%
print('Root Mean Square Error (RMSE)', round(np.sqrt(metrics.mean_squared_error(y_test,preds)),3))
# Out:
# Root Mean Square Error (RMSE) 9.928
